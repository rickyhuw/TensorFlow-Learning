# %%
# 手写体识别数据集
# http://yann.lecun.com/exdb/mnist/
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import warnings
warnings.filterwarnings('ignore')
mnist = input_data.read_data_sets('MNIST_data',one_hot=True)

# batch
batch_size = 100
# 批次数
n_batch = mnist.train.num_examples // batch_size

# learning_rate
learning_rate = 0.2

# 占位符
with tf.name_scope('input'):
    x = tf.placeholder(tf.float32,[None,784],name='x_input')
    y = tf.placeholder(tf.float32,[None,10],name='y_input')
keep_probility = tf.placeholder(tf.float32)
lr = tf.Variable(0.001,dtype=tf.float32)

with tf.name_scope('Layer'):
# 创建一个单层的神经网络
    with tf.name_scope('Weight'):
        W1 = tf.Variable(tf.truncated_normal([784,100],stddev=0.1),name='w')
    with tf.name_scope('Bias'):
        b1 = tf.Variable(tf.zeros([100]) + 0.1,name='b')
    with tf.name_scope("Active"):
        L1 = tf.tanh(tf.matmul(x,W1) + b1,name='tanh')
    with tf.name_scope('DropOut'):
        L1_drop = tf.nn.dropout(L1,keep_prob=keep_probility,name='dropout')

W2 = tf.Variable(tf.truncated_normal([100,50],stddev=0.1))
b2 = tf.Variable(tf.zeros([50]) + 0.1)
L2 = tf.tanh(tf.matmul(L1_drop,W2) + b2)
L2_drop = tf.nn.dropout(L2,keep_prob=keep_probility)

W3 = tf.Variable(tf.truncated_normal([50,30],stddev=0.1))
b3 = tf.Variable(tf.zeros([30]) + 0.1)
L3 = tf.tanh(tf.matmul(L2_drop,W3) + b3)
L3_drop = tf.nn.dropout(L3,keep_prob=keep_probility)

W4 = tf.Variable(tf.truncated_normal([30,10],stddev=0.1))
b4 = tf.Variable(tf.zeros([10]) + 0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4) + b4)

# loss
# loss = tf.reduce_mean(tf.square(y - prediction))

# 使用交叉熵代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))

# train
# train_step = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)
train_step = tf.train.AdamOptimizer(lr).minimize(loss)
# init
init = tf.global_variables_initializer()
# accuracy
correct_predictions = tf.equal(tf.arg_max(y,1),tf.arg_max(prediction,1))
accuracy = tf.reduce_mean(tf.cast(correct_predictions,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    writer = tf.summary.FileWriter('logs/',sess.graph)
    for epoch in range(21):
        sess.run(tf.assign(lr, 0.001 * (0.95 ** epoch)))
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys,keep_probility:0.9})
        lr_rate = sess.run(lr)
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_probility:0.9})
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_probility:0.9})
        print('epoch:'+ str(epoch) + ", Testing Accuracy:" + str(test_acc) + ", Training Accuracy:" + str(train_acc) + ", Learning Rate:" + str(lr_rate))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# epoch:0, Testing Accuracy:0.9229, Training Accuracy:0.9236182, Learning Rate:0.001
# epoch:1, Testing Accuracy:0.9387, Training Accuracy:0.9408, Learning Rate:0.00095
# epoch:2, Testing Accuracy:0.9431, Training Accuracy:0.94747275, Learning Rate:0.0009025
# epoch:3, Testing Accuracy:0.9467, Training Accuracy:0.95196366, Learning Rate:0.000857375
# epoch:4, Testing Accuracy:0.953, Training Accuracy:0.95878184, Learning Rate:0.00081450626
# epoch:5, Testing Accuracy:0.9561, Training Accuracy:0.9606364, Learning Rate:0.0007737809
# epoch:6, Testing Accuracy:0.9563, Training Accuracy:0.9638, Learning Rate:0.0007350919
# epoch:7, Testing Accuracy:0.9586, Training Accuracy:0.9656364, Learning Rate:0.0006983373
# epoch:8, Testing Accuracy:0.9614, Training Accuracy:0.96814543, Learning Rate:0.0006634204
# epoch:9, Testing Accuracy:0.961, Training Accuracy:0.9694545, Learning Rate:0.0006302494
# epoch:10, Testing Accuracy:0.9612, Training Accuracy:0.9703818, Learning Rate:0.0005987369
# epoch:11, Testing Accuracy:0.9598, Training Accuracy:0.9701273, Learning Rate:0.0005688001
# epoch:12, Testing Accuracy:0.965, Training Accuracy:0.9742909, Learning Rate:0.0005403601
# epoch:13, Testing Accuracy:0.9618, Training Accuracy:0.9738909, Learning Rate:0.0005133421
# epoch:14, Testing Accuracy:0.9641, Training Accuracy:0.9743818, Learning Rate:0.000487675
# epoch:15, Testing Accuracy:0.9647, Training Accuracy:0.97441816, Learning Rate:0.00046329122
# epoch:16, Testing Accuracy:0.9651, Training Accuracy:0.9764182, Learning Rate:0.00044012666
# epoch:17, Testing Accuracy:0.9639, Training Accuracy:0.9770909, Learning Rate:0.00041812033
# epoch:18, Testing Accuracy:0.9666, Training Accuracy:0.97745454, Learning Rate:0.00039721432
# epoch:19, Testing Accuracy:0.962, Training Accuracy:0.97725457, Learning Rate:0.0003773536
# epoch:20, Testing Accuracy:0.9655, Training Accuracy:0.9783091, Learning Rate:0.00035848594
